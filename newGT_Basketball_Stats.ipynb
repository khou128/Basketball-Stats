# %% [markdown]
# <a href="https://colab.research.google.com/github/khou128/Basketball-Stats/blob/main/newGT_Basketball_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_1 = 'https://raw.githubusercontent.com/khou128/Basketball-Stats/main/cleaned_basketball_nba.csv'
df_1 = pd.read_csv(url_1)
df_1
# Out:
#        Unnamed: 0       player_name  usg_pct  ts_pct  ast_pct   pts  ast
# 0               0  Randy Livingston    0.169   0.487    0.248   3.9  2.4
# 1               1  Gaylon Nickerson    0.174   0.497    0.043   3.8  0.3
# 2               2      George Lynch    0.175   0.512    0.125   8.3  1.9
# 3               3    George McCloud    0.206   0.527    0.125  10.2  1.7
# 4               4      George Zidek    0.195   0.500    0.064   2.8  0.3
# ...           ...               ...      ...     ...      ...   ...  ...
# 12839       12839       Joel Embiid    0.370   0.655    0.233  33.1  4.2
# 12840       12840   John Butler Jr.    0.102   0.411    0.066   2.4  0.6
# 12841       12841      John Collins    0.168   0.593    0.052  13.1  1.2
# 12842       12842      Jericho Sims    0.074   0.780    0.044   3.4  0.5
# 12843       12843    JaMychal Green    0.169   0.650    0.094   6.4  0.9
#
# [12844 rows x 7 columns]

# %%
from scipy.stats.mstats import winsorize

# Assuming df is your DataFrame and 'column_name' is the column containing the data with extreme values
# For example, let's say you want to winsorize the 'value' column
winsorized_values = winsorize(df_1['usg_pct'], limits=[0.05, 0.05])  # Winsorize values below the 5th percentile and above the 95th percentile

# Replace the original column with the winsorized values
df_1['usg_pct'] = winsorized_values

# %%
from scipy.stats.mstats import winsorize

# Assuming df is your DataFrame and 'column_name' is the column containing the data with extreme values
# For example, let's say you want to winsorize the 'value' column
winsorized_values = winsorize(df_1['ts_pct'], limits=[0.05, 0.05])  # Winsorize values below the 5th percentile and above the 95th percentile

# Replace the original column with the winsorized values
df_1['ts_pct'] = winsorized_values

# %%
from scipy.stats.mstats import winsorize

# Assuming df is your DataFrame and 'column_name' is the column containing the data with extreme values
# For example, let's say you want to winsorize the 'value' column
winsorized_values = winsorize(df_1['ast_pct'], limits=[0.05, 0.05])  # Winsorize values below the 5th percentile and above the 95th percentile

# Replace the original column with the winsorized values
df_1['ast_pct'] = winsorized_values

# %%
df_1
# Out:
#        Unnamed: 0       player_name  usg_pct  ts_pct  ast_pct   pts  ast
# 0               0  Randy Livingston    0.169   0.487    0.248   3.9  2.4
# 1               1  Gaylon Nickerson    0.174   0.497    0.043   3.8  0.3
# 2               2      George Lynch    0.175   0.512    0.125   8.3  1.9
# 3               3    George McCloud    0.206   0.527    0.125  10.2  1.7
# 4               4      George Zidek    0.195   0.500    0.064   2.8  0.3
# ...           ...               ...      ...     ...      ...   ...  ...
# 12839       12839       Joel Embiid    0.276   0.627    0.233  33.1  4.2
# 12840       12840   John Butler Jr.    0.107   0.411    0.066   2.4  0.6
# 12841       12841      John Collins    0.168   0.593    0.052  13.1  1.2
# 12842       12842      Jericho Sims    0.107   0.627    0.044   3.4  0.5
# 12843       12843    JaMychal Green    0.169   0.627    0.094   6.4  0.9
#
# [12844 rows x 7 columns]

# %%
#Mean of True Shooting Percentage:
column_name = 'ts_pct'
mean_value = df_1[column_name].mean()

print("Mean of column '{}' is: {}".format(column_name, mean_value))
# Out:
# Mean of column 'ts_pct' is: 0.5171293989411397

# %%
# Mean of Assist Percentage:
column_name = 'ast_pct'
mean_value = df_1[column_name].mean()

print("Mean of column '{}' is: {}".format(column_name, mean_value))
# Out:
# Mean of column 'ast_pct' is: 0.12933385238243536

# %%
# Mean of Usage Percentage: USG% is a valuable metric for assessing a player's offensive involvement and contribution to the team's scoring efforts.
column_name = 'usg_pct'
mean_value = df_1[column_name].mean()

print("Mean of column '{}' is: {}".format(column_name, mean_value))
# Out:
# Mean of column 'usg_pct' is: 0.18408463095608843

# %%
url_2 = 'https://raw.githubusercontent.com/khou128/Basketball-Stats/main/NEWcleaned_FGA_FTA.csv'
df_2 = pd.read_csv(url_2)
df_2
# Out:
#      Number of Players  FTA   FGA    FT%
# 0                  1.0  1.7   8.7  0.600
# 1                  2.0  1.6   3.0  0.545
# 2                  3.0  4.2   9.7  0.763
# 3                  4.0  1.0   2.0  1.000
# 4                  5.0  0.9   6.8  0.636
# ..                 ...  ...   ...    ...
# 213              214.0  1.8   5.8  0.667
# 214              215.0  0.7   3.0  0.250
# 215              216.0  6.6  13.8  0.788
# 216              217.0  0.3   2.0  0.333
# 217                NaN  NaN   NaN    NaN
#
# [218 rows x 4 columns]

# %%
column_name = 'FT%'
mean_value = df_2[column_name].mean()

print("Mean of column '{}' is: {}".format(column_name, mean_value))
# Out:
# Mean of column 'FT%' is: 0.6232488479262673

# %%
#FGA%:
df_2['FGA%'] = (df_2['FGA'] / (df_2['FGA'] + df_2['FTA'])) * 100
df_2
# Out:
#      Number of Players  FTA   FGA    FT%       FGA%
# 0                  1.0  1.7   8.7  0.600  83.653846
# 1                  2.0  1.6   3.0  0.545  65.217391
# 2                  3.0  4.2   9.7  0.763  69.784173
# 3                  4.0  1.0   2.0  1.000  66.666667
# 4                  5.0  0.9   6.8  0.636  88.311688
# ..                 ...  ...   ...    ...        ...
# 213              214.0  1.8   5.8  0.667  76.315789
# 214              215.0  0.7   3.0  0.250  81.081081
# 215              216.0  6.6  13.8  0.788  67.647059
# 216              217.0  0.3   2.0  0.333  86.956522
# 217                NaN  NaN   NaN    NaN        NaN
#
# [218 rows x 5 columns]

# %%
column_name = 'FGA%'
mean_value = df_2[column_name].mean()

print("Mean of column '{}' is: {}".format(column_name, mean_value))
# Out:
# Mean of column 'FGA%' is: 81.2382793811144
